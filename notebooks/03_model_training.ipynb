# %% [markdown]
# # Model Training and Evaluation
# This notebook:
# - Loads the processed training and test datasets
# - Builds and trains a neural network classifier
# - Handles class imbalance using class weights
# - Evaluates model performance using classification metrics and confusion matrix
# - Saves the final trained model for deployment

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.utils import class_weight
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow import keras

# %% [markdown]
# ## Load Train-Test data

# %%
X_train = pd.read_csv('../data/X_train.csv')
X_test = pd.read_csv('../data/X_test.csv')
y_train = pd.read_csv('../data/y_train.csv').values.ravel()
y_test = pd.read_csv('../data/y_test.csv').values.ravel()

# %% [markdown]
# ## Build Neural Network

# %%
model = keras.Sequential([
    keras.Input(shape=(X_train.shape[1],)),
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy')

# %% [markdown]
# ## Training Model

# %%
weights = class_weight.compute_class_weight(class_weight='balanced', classes=np.unique(y_train), y=y_train)

model.fit(X_train, y_train, epochs=50, class_weight=dict(enumerate(weights)))
# Out:
# Epoch 1/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.5583
# Epoch 2/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4886
# Epoch 3/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4806
# Epoch 4/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4764
# Epoch 5/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step - loss: 0.4742
# Epoch 6/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 836us/step - loss: 0.4728
# Epoch 7/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step - loss: 0.4696
# Epoch 8/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4688
# Epoch 9/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - loss: 0.4693
# Epoch 10/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - loss: 0.4653
# Epoch 11/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step - loss: 0.4654
# Epoch 12/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 821us/step - loss: 0.4638
# Epoch 13/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 894us/step - loss: 0.4626
# Epoch 14/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step - loss: 0.4619
# Epoch 15/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4597
# Epoch 16/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - loss: 0.4597
# Epoch 17/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4580
# Epoch 18/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 972us/step - loss: 0.4566
# Epoch 19/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - loss: 0.4556
# Epoch 20/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step - loss: 0.4547
# Epoch 21/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step - loss: 0.4536
# Epoch 22/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 836us/step - loss: 0.4521
# Epoch 23/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 786us/step - loss: 0.4499
# Epoch 24/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step - loss: 0.4490
# Epoch 25/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 985us/step - loss: 0.4468
# Epoch 26/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step - loss: 0.4464
# Epoch 27/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4447
# Epoch 28/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4435
# Epoch 29/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step - loss: 0.4430
# Epoch 30/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - loss: 0.4409
# Epoch 31/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4419
# Epoch 32/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step - loss: 0.4377
# Epoch 33/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 823us/step - loss: 0.4363
# Epoch 34/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - loss: 0.4355
# Epoch 35/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step - loss: 0.4329
# Epoch 36/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step - loss: 0.4318
# Epoch 37/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4308
# Epoch 38/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step - loss: 0.4283
# Epoch 39/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step - loss: 0.4284
# Epoch 40/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step - loss: 0.4265
# Epoch 41/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 843us/step - loss: 0.4255
# Epoch 42/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step - loss: 0.4224
# Epoch 43/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - loss: 0.4218
# Epoch 44/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step - loss: 0.4220
# Epoch 45/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 822us/step - loss: 0.4191
# Epoch 46/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 830us/step - loss: 0.4186
# Epoch 47/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step - loss: 0.4169
# Epoch 48/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 815us/step - loss: 0.4167
# Epoch 49/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 841us/step - loss: 0.4143
# Epoch 50/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step - loss: 0.4137

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# ### Classification Report

# %%
y_pred = (model.predict(X_test) > 0.5).astype(int)
print(classification_report(y_test, y_pred))
# Out:
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#               precision    recall  f1-score   support
#
#            0       0.91      0.70      0.79      1033
#            1       0.50      0.81      0.62       374
#
#     accuracy                           0.73      1407
#    macro avg       0.70      0.76      0.71      1407
# weighted avg       0.80      0.73      0.75      1407

# %% [markdown]
# ### Confusion Matrix

# %%
plt.figure(figsize=(6,5))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
# Out:
# Text(45.722222222222214, 0.5, 'True')

# %% [markdown]
# ## Save the Model

# %%
model.save("../models/final_model.keras")
